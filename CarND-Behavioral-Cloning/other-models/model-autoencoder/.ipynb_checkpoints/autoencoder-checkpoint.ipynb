# %%
import csv
import cv2
import numpy as np
import sklearn
import os

def load_samples(file):
    '''
    Load driving_log generated by the simulator.
    '''
    samples = []
    with open(file) as csvfile:
        reader = csv.reader(csvfile)
        for line in reader:
            samples.append(line)
    
    return samples

def generator(samples, batch_size=16, grayscale=False, 
              img_folder='../../data/IMG_udacity/', sequence_length=10):
    '''
    Generate batches in a memory-efficient way. 
    '''
    num_samples = len(samples)
    count = 0
    
    while 1: # Loop forever so the generator never terminates
        
        sklearn.utils.shuffle(samples)
        
        for offset in range(0, num_samples, batch_size):
            
            images = []
            angles = []
            
            for offset_seq in range(offset, offset + batch_size):
                
                #print(offset, offset_seq)
                #count += 1
                seq_samples = samples[offset_seq:offset_seq+sequence_length]
                
                #print(len(seq_samples))
                
                images_seq = []
                angles_seq = []

                for seq_sample in seq_samples:
                    name = os.path.join(img_folder, seq_sample[0].split('/')[-1])
                    center_image = cv2.imread(name)

                    if grayscale:
                        center_image = cv2.cvtColor(center_image, cv2.COLOR_BGR2GRAY)
                        center_image = center_image.reshape(center_image.shape + (1,))

                    try:
                        #center_angle = float(seq_sample[3])
                        center_angle = int((float(seq_sample[3]) + 1.) * 49)
                    except ValueError:
                        print("value is not a number")
                        continue

                    # resize image
                    center_image = cv2.resize(center_image, None, 
                                              fx=0.125, fy=0.125, 
                                              interpolation=cv2.INTER_CUBIC)

                    '''if count % 2 == 0: # Flipping Images And Steering Measurements
                        center_image = np.fliplr(center_image)
                        center_angle = -center_angle'''

                    images_seq.append(center_image)
                    angles_seq.append(center_angle)
                
                #print(len(angles_seq))
                
                if len(angles_seq) == 0:
                    break
                
                # padding
                padding = angles_seq[-1]
                for i in range(abs(len(angles_seq) - sequence_length)):
                    angles_seq.append(padding)
                
                images.append(images_seq)
                angles.append(angles_seq)
                
            # trim image to only see section with road
            images = np.array(images)
            angles = np.array(angles)
            #print(angles.shape)
            #angles = angles.reshape(angles.shape[0], angles.shape[1], -1)
            #yield sklearn.utils.shuffle(X_train, y_train)
            #yield (images, angles)
            yield (angles, angles)

# %%
samples = load_samples('../../data/driving_log_udacity.csv')
angle_generator = generator(samples)
next(angle_generator)[0].shape
# Out:
# (16, 10)

# %%
from keras.layers import LSTM, RepeatVector, Input, Dropout, Embedding
from keras.models import Model

SEQUENCE_LENGTH = 5
EMBEDDING_SHAPE = 50
VOCAB_SIZE = 100

inputs = Input(shape=(SEQUENCE_LENGTH,))

embedding = Embedding(VOCAB_SIZE, EMBEDDING_SHAPE, 
                      input_length=SEQUENCE_LENGTH,
                      #weights=[embeddings], 
                      mask_zero=False)(inputs)
#embedding.trainable = False'''

encoded = LSTM(300, 
               input_shape=(None, EMBEDDING_SHAPE),
               return_sequences=True)(embedding)

encoded = LSTM(EMBEDDING_SHAPE)(encoded)

decoded = RepeatVector(SEQUENCE_LENGTH)(encoded)
decoded = LSTM(EMBEDDING_SHAPE, return_sequences=True)(decoded)

#decoded = Dropout(0.2)(decoded)

decoded = LSTM(EMBEDDING_SHAPE, return_sequences=True)(decoded)

model = Model(inputs, decoded)
encoder = Model(inputs, encoded)

model.compile(loss='cosine_proximity', optimizer='adam')
#model.compile(loss='mse', optimizer='adam')

model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_33 (InputLayer)            (None, 5)             0
# ____________________________________________________________________________________________________
# embedding_9 (Embedding)          (None, 5, 50)         5000        input_33[0][0]
# ____________________________________________________________________________________________________
# lstm_93 (LSTM)                   (None, 5, 300)        421200      embedding_9[0][0]
# ____________________________________________________________________________________________________
# lstm_94 (LSTM)                   (None, 50)            70200       lstm_93[0][0]
# ____________________________________________________________________________________________________
# repeatvector_20 (RepeatVector)   (None, 5, 50)         0           lstm_94[0][0]
# ____________________________________________________________________________________________________
# lstm_95 (LSTM)                   (None, 5, 50)         20200       repeatvector_20[0][0]
# ____________________________________________________________________________________________________
# lstm_96 (LSTM)                   (None, 5, 50)         20200       lstm_95[0][0]
# ====================================================================================================
# Total params: 536,800
# Trainable params: 536,800
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
from sklearn.metrics.pairwise import cosine_similarity

def get_most_similar(query, vecs, vocabulary=None, k=3):
    cosine = cosine_similarity(query.reshape(1,-1), vecs)[0]
    max_idxs = np.array(cosine).argsort()[::-1]
    #mask = np.in1d(max_idxs, list(vocabulary.keys()))
    #max_idxs = max_idxs[mask][:k]
    max_idxs = max_idxs[:k]
    #print('result', max_idxs)
    #return ['' if vocabulary.get(idx) == '</PAD>' else vocabulary.get(idx) for idx in max_idxs]
    return max_idxs

# %%
from sklearn.model_selection import train_test_split
from keras.callbacks import CSVLogger

BATCH_SIZE = 32
NUM_EPOCHS = 1000

# read driving_log.csv
samples = load_samples('../../data/driving_log_udacity.csv')

# train/validation split
train_samples, validation_samples = train_test_split(samples, test_size=0.2)

# train/validation generators
train_generator = generator(train_samples, batch_size=BATCH_SIZE, sequence_length=SEQUENCE_LENGTH)
validation_generator = generator(validation_samples, batch_size=BATCH_SIZE, sequence_length=SEQUENCE_LENGTH)


print('training...')
    
#csv_logger = CSVLogger('./training.log')

for iteration in range(1, NUM_EPOCHS):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    
    X, y = next(train_generator)
    X_val, y_val = next(validation_generator)

    model.fit(X, np.array([model.layers[1].get_weights()[0][xt] for xt in X]), 
              batch_size=BATCH_SIZE, nb_epoch=1,
              validation_data=(X_val, np.array([model.layers[1].get_weights()[0][xt] for xt in X_val])), 
              verbose=1)
    
    # Select samples from the validation set at random so we can visualize errors.
    for i in range(1):

        ind = np.random.randint(0, len(X_val))
        test = np.array(X_val[ind]).reshape(1, SEQUENCE_LENGTH)

        print('Orig:', test.reshape(SEQUENCE_LENGTH).tolist())
        
        #preds = autoencoder.predict(rowx, verbose=0)
        pred = model.predict(test, verbose=0)
        
        #print(get_most_similar(pred[0][0], model.layers[1].get_weights()[0])[0])
        #print('Prediction:', pred[0].reshape(SEQUENCE_LENGTH)[:5])
        
        print('Pred:', [get_most_similar(word_vec, 
                                             model.layers[1].get_weights()[0])[0] for word_vec in pred[0]])

# training
'''history = model.fit_generator(train_generator, 
                              samples_per_epoch=len(train_samples), 
                              validation_data=validation_generator, 
                              nb_val_samples=len(validation_samples), 
                              nb_epoch=NUM_EPOCHS)'''
# save model
#model.save("model-autoencoder.h5", True)
# Out:
# training...
#
# --------------------------------------------------
# Iteration 1
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 5s - loss: 3.0557e-04 - val_loss: -0.0042
# Orig: [49, 49, 49, 70, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 2
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0044 - val_loss: -0.0073
# Orig: [49, 49, 49, 49, 46]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 3
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0066 - val_loss: -0.0081
# Orig: [49, 49, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 4
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0067 - val_loss: -0.0083
# Orig: [49, 49, 50, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 5
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0090 - val_loss: -0.0094
# Orig: [49, 49, 49, 39, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 6
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0112 - val_loss: -0.0111
# Orig: [49, 49, 63, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 7
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0100 - val_loss: -0.0108
# Orig: [49, 49, 54, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 8
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0096 - val_loss: -0.0102
# Orig: [49, 57, 52, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 9
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0126 - val_loss: -0.0125
# Orig: [49, 49, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 10
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0122 - val_loss: -0.0135
# Orig: [49, 34, 49, 49, 64]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 11
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0111 - val_loss: -0.0111
# Orig: [42, 49, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 12
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0094 - val_loss: -0.0110
# Orig: [49, 49, 56, 56, 39]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 13
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0141 - val_loss: -0.0097
# Orig: [49, 66, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 14
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0118 - val_loss: -0.0084
# Orig: [49, 49, 49, 42, 45]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 15
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0103 - val_loss: -0.0098
# Orig: [51, 49, 49, 57, 51]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 16
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0121 - val_loss: -0.0105
# Orig: [49, 52, 60, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 17
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0125 - val_loss: -0.0109
# Orig: [49, 49, 57, 46, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 18
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0120 - val_loss: -0.0113
# Orig: [49, 47, 48, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 19
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0114 - val_loss: -0.0104
# Orig: [49, 67, 53, 49, 45]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 20
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0122 - val_loss: -0.0095
# Orig: [49, 49, 49, 48, 51]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 21
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0130 - val_loss: -0.0126
# Orig: [49, 57, 49, 49, 46]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 22
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0108 - val_loss: -0.0121
# Orig: [49, 49, 50, 57, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 23
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0115 - val_loss: -0.0119
# Orig: [51, 63, 49, 53, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 24
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0071 - val_loss: -0.0095
# Orig: [51, 49, 49, 41, 51]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 25
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0102 - val_loss: -0.0103
# Orig: [49, 45, 53, 36, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 26
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0092 - val_loss: -0.0113
# Orig: [35, 57, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 27
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0140 - val_loss: -0.0120
# Orig: [52, 47, 56, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 28
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0121 - val_loss: -0.0112
# Orig: [40, 46, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 29
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0121 - val_loss: -0.0083
# Orig: [49, 49, 45, 48, 47]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 30
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0114 - val_loss: -0.0107
# Orig: [49, 49, 49, 47, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 31
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0095 - val_loss: -0.0117
# Orig: [49, 47, 47, 67, 43]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 32
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0090 - val_loss: -0.0125
# Orig: [50, 49, 49, 49, 64]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 33
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0114 - val_loss: -0.0085
# Orig: [48, 49, 37, 53, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 34
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0111 - val_loss: -0.0095
# Orig: [57, 49, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 35
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0085 - val_loss: -0.0088
# Orig: [49, 62, 49, 58, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 36
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0132 - val_loss: -0.0115
# Orig: [40, 49, 49, 53, 59]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 37
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0120 - val_loss: -0.0105
# Orig: [49, 53, 49, 49, 51]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 38
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0132 - val_loss: -0.0121
# Orig: [57, 49, 49, 53, 57]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 39
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0117 - val_loss: -0.0119
# Orig: [49, 49, 47, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 40
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0130 - val_loss: -0.0109
# Orig: [49, 51, 49, 64, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 41
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0114 - val_loss: -0.0118
# Orig: [49, 58, 47, 63, 45]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 42
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0122 - val_loss: -0.0114
# Orig: [49, 53, 49, 49, 46]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 43
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0116 - val_loss: -0.0123
# Orig: [49, 53, 44, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 44
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0086 - val_loss: -0.0110
# Orig: [49, 44, 52, 57, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 45
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0154 - val_loss: -0.0110
# Orig: [36, 49, 45, 52, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 46
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0112 - val_loss: -0.0118
# Orig: [49, 47, 49, 49, 46]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 47
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0129 - val_loss: -0.0130
# Orig: [49, 26, 57, 45, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 48
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0121 - val_loss: -0.0129
# Orig: [58, 49, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 49
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0127 - val_loss: -0.0087
# Orig: [55, 71, 49, 49, 42]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 50
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0087 - val_loss: -0.0119
# Orig: [53, 49, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 51
# Train on 32 samples, validate on 8 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0090 - val_loss: -0.0103
# Orig: [49, 49, 51, 51, 51]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 52
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0103 - val_loss: -0.0110
# Orig: [51, 49, 49, 49, 42]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 53
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0104 - val_loss: -0.0115
# Orig: [49, 57, 51, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 54
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0113 - val_loss: -0.0107
# Orig: [49, 54, 46, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 55
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0118 - val_loss: -0.0105
# Orig: [49, 52, 51, 33, 41]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 56
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0133 - val_loss: -0.0111
# Orig: [38, 49, 59, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 57
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0127 - val_loss: -0.0130
# Orig: [49, 49, 53, 45, 18]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 58
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0104 - val_loss: -0.0122
# Orig: [49, 49, 55, 62, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 59
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0129 - val_loss: -0.0109
# Orig: [49, 49, 53, 45, 55]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 60
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0156 - val_loss: -0.0133
# Orig: [49, 49, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 61
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0116 - val_loss: -0.0139
# Orig: [49, 49, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 62
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0118 - val_loss: -0.0116
# Orig: [49, 49, 46, 42, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 63
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0100 - val_loss: -0.0111
# Orig: [57, 49, 48, 45, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 64
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0104 - val_loss: -0.0101
# Orig: [51, 57, 47, 43, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 65
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0123 - val_loss: -0.0087
# Orig: [35, 49, 41, 49, 45]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 66
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0097 - val_loss: -0.0103
# Orig: [49, 51, 51, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 67
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0127 - val_loss: -0.0110
# Orig: [52, 60, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 68
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0120 - val_loss: -0.0109
# Orig: [49, 41, 57, 45, 41]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 69
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0121 - val_loss: -0.0115
# Orig: [48, 49, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 70
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0128 - val_loss: -0.0104
# Orig: [49, 50, 24, 49, 67]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 71
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0120 - val_loss: -0.0098
# Orig: [52, 67, 44, 52, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 72
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0100 - val_loss: -0.0126
# Orig: [43, 49, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 73
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0136 - val_loss: -0.0123
# Orig: [56, 49, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 74
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0118 - val_loss: -0.0123
# Orig: [43, 49, 49, 51, 63]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 75
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0097 - val_loss: -0.0099
# Orig: [53, 49, 45, 62, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 76
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0107 - val_loss: -0.0105
# Orig: [49, 51, 49, 45, 53]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 77
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0106 - val_loss: -0.0113
# Orig: [35, 57, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 78
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0101 - val_loss: -0.0117
# Orig: [49, 41, 49, 44, 62]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 79
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0124 - val_loss: -0.0111
# Orig: [37, 49, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 80
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0118 - val_loss: -0.0084
# Orig: [40, 45, 53, 63, 46]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 81
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0110 - val_loss: -0.0108
# Orig: [57, 34, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 82
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0114 - val_loss: -0.0115
# Orig: [49, 49, 37, 52, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 83
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0101 - val_loss: -0.0127
# Orig: [49, 49, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 84
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0115 - val_loss: -0.0087
# Orig: [31, 49, 49, 49, 35]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 85
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0086 - val_loss: -0.0097
# Orig: [49, 53, 42, 49, 62]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 86
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0098 - val_loss: -0.0091
# Orig: [34, 49, 41, 55, 52]
# Pred: [49, 49, 41, 41, 41]
#
# --------------------------------------------------
# Iteration 87
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0124 - val_loss: -0.0116
# Orig: [47, 49, 40, 40, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 88
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0103 - val_loss: -0.0105
# Orig: [46, 53, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 89
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0107 - val_loss: -0.0121
# Orig: [49, 53, 57, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 90
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0085 - val_loss: -0.0118
# Orig: [53, 49, 49, 47, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 91
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0100 - val_loss: -0.0106
# Orig: [49, 41, 52, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 92
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0087 - val_loss: -0.0117
# Orig: [49, 62, 49, 59, 38]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 93
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0145 - val_loss: -0.0114
# Orig: [49, 49, 66, 45, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 94
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0125 - val_loss: -0.0121
# Orig: [39, 49, 36, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 95
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0112 - val_loss: -0.0109
# Orig: [49, 49, 49, 49, 46]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 96
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0117 - val_loss: -0.0109
# Orig: [52, 49, 46, 55, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 97
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0129 - val_loss: -0.0115
# Orig: [49, 57, 40, 49, 41]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 98
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0112 - val_loss: -0.0130
# Orig: [49, 51, 49, 66, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 99
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0114 - val_loss: -0.0126
# Orig: [44, 49, 58, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 100
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0138 - val_loss: -0.0094
# Orig: [42, 49, 53, 57, 43]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 101
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0118 - val_loss: -0.0118
# Orig: [53, 42, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 102
# Train on 32 samples, validate on 8 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0101 - val_loss: -0.0124
# Orig: [81, 49, 49, 49, 51]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 103
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0115 - val_loss: -0.0112
# Orig: [49, 49, 42, 52, 54]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 104
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0118 - val_loss: -0.0116
# Orig: [68, 50, 49, 49, 52]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 105
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0095 - val_loss: -0.0109
# Orig: [53, 57, 49, 36, 38]
# Pred: [53, 53, 53, 53, 53]
#
# --------------------------------------------------
# Iteration 106
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0127 - val_loss: -0.0106
# Orig: [49, 52, 51, 33, 41]
# Pred: [49, 49, 52, 52, 52]
#
# --------------------------------------------------
# Iteration 107
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0115 - val_loss: -0.0113
# Orig: [43, 49, 49, 49, 39]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 108
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0114 - val_loss: -0.0129
# Orig: [55, 50, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 109
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0099 - val_loss: -0.0122
# Orig: [49, 53, 51, 53, 38]
# Pred: [49, 49, 49, 53, 53]
#
# --------------------------------------------------
# Iteration 110
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0101 - val_loss: -0.0107
# Orig: [49, 49, 57, 52, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 111
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0105 - val_loss: -0.0133
# Orig: [49, 49, 49, 49, 57]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 112
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0109 - val_loss: -0.0137
# Orig: [49, 34, 49, 49, 64]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 113
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0123 - val_loss: -0.0117
# Orig: [54, 49, 49, 46, 42]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 114
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0133 - val_loss: -0.0109
# Orig: [45, 49, 49, 38, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 115
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0112 - val_loss: -0.0103
# Orig: [38, 49, 49, 53, 27]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 116
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0111 - val_loss: -0.0085
# Orig: [51, 49, 57, 38, 47]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 117
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0105 - val_loss: -0.0102
# Orig: [49, 45, 53, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 118
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0143 - val_loss: -0.0109
# Orig: [71, 49, 49, 60, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 119
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0112 - val_loss: -0.0108
# Orig: [49, 38, 49, 51, 57]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 120
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0102 - val_loss: -0.0114
# Orig: [43, 49, 41, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 121
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0120 - val_loss: -0.0102
# Orig: [49, 49, 49, 51, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 122
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0121 - val_loss: -0.0099
# Orig: [49, 49, 48, 51, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 123
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0102 - val_loss: -0.0124
# Orig: [43, 49, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 124
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0115 - val_loss: -0.0122
# Orig: [50, 49, 57, 49, 45]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 125
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0118 - val_loss: -0.0122
# Orig: [47, 49, 57, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 126
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0102 - val_loss: -0.0100
# Orig: [49, 49, 41, 51, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 127
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0121 - val_loss: -0.0107
# Orig: [49, 28, 53, 49, 52]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 128
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0100 - val_loss: -0.0113
# Orig: [49, 49, 49, 49, 57]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 129
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0109 - val_loss: -0.0114
# Orig: [38, 49, 67, 66, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 130
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0110 - val_loss: -0.0110
# Orig: [49, 49, 49, 41, 57]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 131
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0087 - val_loss: -0.0080
# Orig: [49, 49, 45, 48, 47]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 132
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0120 - val_loss: -0.0110
# Orig: [49, 55, 46, 49, 55]
# Pred: [49, 49, 49, 49, 55]
#
# --------------------------------------------------
# Iteration 133
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0115 - val_loss: -0.0116
# Orig: [47, 49, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 134
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0123 - val_loss: -0.0130
# Orig: [42, 49, 49, 50, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 135
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0125 - val_loss: -0.0087
# Orig: [52, 42, 53, 49, 72]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 136
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0115 - val_loss: -0.0099
# Orig: [48, 52, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 137
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0130 - val_loss: -0.0093
# Orig: [41, 34, 49, 41, 55]
# Pred: [41, 41, 41, 41, 41]
#
# --------------------------------------------------
# Iteration 138
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0100 - val_loss: -0.0115
# Orig: [49, 45, 38, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 139
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0113 - val_loss: -0.0108
# Orig: [38, 36, 46, 46, 53]
# Pred: [62, 62, 46, 46, 46]
#
# --------------------------------------------------
# Iteration 140
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0087 - val_loss: -0.0120
# Orig: [43, 42, 49, 64, 45]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 141
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0119 - val_loss: -0.0118
# Orig: [48, 43, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 142
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0097 - val_loss: -0.0104
# Orig: [49, 45, 49, 45, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 143
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0127 - val_loss: -0.0117
# Orig: [46, 47, 49, 49, 55]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 144
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0093 - val_loss: -0.0116
# Orig: [41, 41, 44, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 145
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0104 - val_loss: -0.0121
# Orig: [57, 56, 49, 46, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 146
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0088 - val_loss: -0.0111
# Orig: [49, 49, 46, 49, 44]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 147
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0117 - val_loss: -0.0107
# Orig: [53, 49, 41, 53, 33]
# Pred: [53, 53, 53, 53, 53]
#
# --------------------------------------------------
# Iteration 148
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0108 - val_loss: -0.0114
# Orig: [49, 49, 38, 45, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 149
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0105 - val_loss: -0.0128
# Orig: [49, 66, 49, 26, 48]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 150
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0125 - val_loss: -0.0126
# Orig: [46, 49, 44, 49, 58]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 151
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0133 - val_loss: -0.0102
# Orig: [57, 43, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 152
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0113 - val_loss: -0.0116
# Orig: [49, 53, 42, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 153
# Train on 32 samples, validate on 8 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0096 - val_loss: -0.0138
# Orig: [81, 49, 49, 49, 51]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 154
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0117 - val_loss: -0.0114
# Orig: [49, 49, 70, 49, 51]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 155
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0110 - val_loss: -0.0115
# Orig: [49, 49, 49, 46, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 156
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0126 - val_loss: -0.0109
# Orig: [66, 59, 49, 49, 46]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 157
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0113 - val_loss: -0.0106
# Orig: [47, 66, 49, 49, 50]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 158
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0112 - val_loss: -0.0116
# Orig: [49, 49, 45, 49, 57]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 159
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0119 - val_loss: -0.0126
# Orig: [39, 49, 49, 49, 45]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 160
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0100 - val_loss: -0.0124
# Orig: [49, 49, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 161
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0136 - val_loss: -0.0107
# Orig: [45, 49, 49, 49, 60]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 162
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0090 - val_loss: -0.0132
# Orig: [51, 49, 49, 48, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 163
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0121 - val_loss: -0.0135
# Orig: [49, 49, 49, 49, 47]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 164
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0114 - val_loss: -0.0117
# Orig: [49, 49, 41, 49, 28]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 165
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0089 - val_loss: -0.0110
# Orig: [56, 49, 37, 41, 49]
# Pred: [49, 49, 37, 37, 37]
#
# --------------------------------------------------
# Iteration 166
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0106 - val_loss: -0.0104
# Orig: [49, 51, 57, 47, 43]
# Pred: [47, 47, 47, 47, 47]
#
# --------------------------------------------------
# Iteration 167
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0106 - val_loss: -0.0088
# Orig: [49, 41, 49, 45, 53]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 168
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0126 - val_loss: -0.0104
# Orig: [49, 49, 48, 52, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 169
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0118 - val_loss: -0.0110
# Orig: [57, 45, 49, 49, 55]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 170
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0109 - val_loss: -0.0109
# Orig: [41, 67, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 171
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0090 - val_loss: -0.0117
# Orig: [49, 48, 53, 33, 56]
# Pred: [53, 53, 53, 53, 53]
#
# --------------------------------------------------
# Iteration 172
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0112 - val_loss: -0.0102
# Orig: [40, 49, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 173
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0088 - val_loss: -0.0103
# Orig: [49, 49, 49, 49, 48]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 174
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0095 - val_loss: -0.0125
# Orig: [51, 49, 41, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 175
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0104 - val_loss: -0.0119
# Orig: [49, 26, 49, 41, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 176
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0099 - val_loss: -0.0120
# Orig: [49, 49, 45, 49, 53]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 177
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0144 - val_loss: -0.0103
# Orig: [57, 40, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 178
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0125 - val_loss: -0.0110
# Orig: [49, 74, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 179
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0082 - val_loss: -0.0115
# Orig: [57, 49, 53, 55, 52]
# Pred: [53, 53, 53, 53, 53]
#
# --------------------------------------------------
# Iteration 180
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0127 - val_loss: -0.0114
# Orig: [49, 49, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 181
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0110 - val_loss: -0.0109
# Orig: [49, 49, 49, 57, 55]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 182
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0106 - val_loss: -0.0086
# Orig: [41, 49, 49, 41, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 183
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0097 - val_loss: -0.0111
# Orig: [71, 57, 34, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 184
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0114 - val_loss: -0.0116
# Orig: [49, 37, 52, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 185
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0098 - val_loss: -0.0133
# Orig: [49, 49, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 186
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0133 - val_loss: -0.0088
# Orig: [49, 64, 49, 52, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 187
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0096 - val_loss: -0.0101
# Orig: [53, 42, 49, 62, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 188
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0142 - val_loss: -0.0095
# Orig: [62, 49, 49, 41, 34]
# Pred: [49, 49, 49, 41, 41]
#
# --------------------------------------------------
# Iteration 189
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0115 - val_loss: -0.0117
# Orig: [49, 49, 45, 49, 48]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 190
# ...
# Iteration 938
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0161 - val_loss: -0.0152
# Orig: [49, 49, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 939
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0154 - val_loss: -0.0154
# Orig: [49, 46, 49, 49, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 940
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0158 - val_loss: -0.0147
# Orig: [34, 49, 57, 56, 49]
# Pred: [80, 80, 57, 80, 49]
#
# --------------------------------------------------
# Iteration 941
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0154 - val_loss: -0.0154
# Orig: [49, 45, 49, 53, 49]
# Pred: [49, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 942
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0151 - val_loss: -0.0141
# Orig: [48, 49, 49, 49, 49]
# Pred: [48, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 943
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0155 - val_loss: -0.0137
# Orig: [49, 51, 49, 45, 53]
# Pred: [49, 49, 49, 45, 11]
#
# --------------------------------------------------
# Iteration 944
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0136 - val_loss: -0.0164
# Orig: [57, 49, 53, 55, 52]
# Pred: [57, 49, 55, 53, 9]
#
# --------------------------------------------------
# Iteration 945
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0152 - val_loss: -0.0152
# Orig: [49, 49, 52, 47, 56]
# Pred: [49, 49, 52, 9, 9]
#
# --------------------------------------------------
# Iteration 946
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0137 - val_loss: -0.0156
# Orig: [49, 49, 49, 41, 57]
# Pred: [49, 49, 49, 41, 11]
#
# --------------------------------------------------
# Iteration 947
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0169 - val_loss: -0.0131
# Orig: [49, 35, 59, 53, 41]
# Pred: [49, 35, 11, 11, 18]
#
# --------------------------------------------------
# Iteration 948
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0140 - val_loss: -0.0151
# Orig: [55, 49, 49, 49, 49]
# Pred: [55, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 949
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0142 - val_loss: -0.0161
# Orig: [47, 49, 49, 49, 49]
# Pred: [47, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 950
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0139 - val_loss: -0.0164
# Orig: [49, 49, 45, 43, 49]
# Pred: [49, 49, 45, 45, 49]
#
# --------------------------------------------------
# Iteration 951
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0162 - val_loss: -0.0123
# Orig: [49, 72, 24, 35, 49]
# Pred: [49, 72, 9, 24, 49]
#
# --------------------------------------------------
# Iteration 952
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0152 - val_loss: -0.0145
# Orig: [48, 45, 49, 55, 39]
# Pred: [48, 48, 48, 48, 11]
#
# --------------------------------------------------
# Iteration 953
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0148 - val_loss: -0.0136
# Orig: [57, 38, 49, 49, 49]
# Pred: [57, 57, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 954
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0161 - val_loss: -0.0151
# Orig: [45, 49, 49, 49, 45]
# Pred: [45, 49, 49, 49, 45]
#
# --------------------------------------------------
# Iteration 955
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0171 - val_loss: -0.0150
# Orig: [36, 46, 46, 53, 49]
# Pred: [46, 46, 46, 46, 49]
#
# --------------------------------------------------
# Iteration 956
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0155 - val_loss: -0.0163
# Orig: [43, 42, 49, 64, 45]
# Pred: [43, 22, 49, 43, 11]
#
# --------------------------------------------------
# Iteration 957
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0125 - val_loss: -0.0164
# Orig: [42, 46, 52, 66, 66]
# Pred: [46, 9, 9, 9, 9]
#
# --------------------------------------------------
# Iteration 958
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0153 - val_loss: -0.0137
# Orig: [49, 49, 46, 49, 49]
# Pred: [49, 49, 46, 49, 49]
#
# --------------------------------------------------
# Iteration 959
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0161 - val_loss: -0.0163
# Orig: [49, 49, 33, 49, 62]
# Pred: [49, 49, 49, 49, 33]
#
# --------------------------------------------------
# Iteration 960
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0164 - val_loss: -0.0151
# Orig: [49, 66, 45, 49, 54]
# Pred: [49, 66, 66, 49, 49]
#
# --------------------------------------------------
# Iteration 961
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0154 - val_loss: -0.0159
# Orig: [49, 49, 49, 49, 45]
# Pred: [49, 49, 49, 49, 45]
#
# --------------------------------------------------
# Iteration 962
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0150 - val_loss: -0.0153
# Orig: [49, 44, 52, 57, 49]
# Pred: [49, 44, 74, 57, 49]
#
# --------------------------------------------------
# Iteration 963
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0159 - val_loss: -0.0144
# Orig: [36, 49, 45, 52, 49]
# Pred: [80, 45, 45, 0, 49]
#
# --------------------------------------------------
# Iteration 964
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0141 - val_loss: -0.0156
# Orig: [49, 51, 41, 49, 49]
# Pred: [49, 51, 51, 49, 49]
#
# --------------------------------------------------
# Iteration 965
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0165 - val_loss: -0.0160
# Orig: [49, 49, 45, 49, 49]
# Pred: [49, 49, 45, 49, 49]
#
# --------------------------------------------------
# Iteration 966
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0135 - val_loss: -0.0154
# Orig: [49, 45, 49, 49, 42]
# Pred: [49, 49, 49, 49, 42]
#
# --------------------------------------------------
# Iteration 967
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0161 - val_loss: -0.0146
# Orig: [49, 49, 42, 49, 49]
# Pred: [49, 49, 42, 49, 49]
#
# --------------------------------------------------
# Iteration 968
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0153 - val_loss: -0.0157
# Orig: [49, 49, 49, 56, 49]
# Pred: [49, 49, 49, 56, 49]
#
# --------------------------------------------------
# Iteration 969
# Train on 32 samples, validate on 8 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0139 - val_loss: -0.0166
# Orig: [49, 49, 51, 51, 51]
# Pred: [49, 49, 51, 51, 51]
#
# --------------------------------------------------
# Iteration 970
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0149 - val_loss: -0.0158
# Orig: [49, 49, 15, 53, 49]
# Pred: [49, 49, 49, 53, 49]
#
# --------------------------------------------------
# Iteration 971
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0146 - val_loss: -0.0152
# Orig: [49, 51, 41, 49, 49]
# Pred: [49, 51, 51, 49, 49]
#
# --------------------------------------------------
# Iteration 972
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0152 - val_loss: -0.0148
# Orig: [49, 54, 46, 49, 49]
# Pred: [49, 54, 46, 49, 49]
#
# --------------------------------------------------
# Iteration 973
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0151 - val_loss: -0.0153
# Orig: [47, 66, 49, 49, 50]
# Pred: [47, 66, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 974
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0144 - val_loss: -0.0151
# Orig: [49, 49, 39, 49, 49]
# Pred: [49, 49, 39, 49, 49]
#
# --------------------------------------------------
# Iteration 975
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0137 - val_loss: -0.0156
# Orig: [49, 64, 49, 45, 49]
# Pred: [49, 49, 49, 45, 49]
#
# --------------------------------------------------
# Iteration 976
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0155 - val_loss: -0.0164
# Orig: [49, 49, 53, 37, 56]
# Pred: [49, 49, 37, 9, 9]
#
# --------------------------------------------------
# Iteration 977
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0132 - val_loss: -0.0150
# Orig: [38, 49, 49, 49, 49]
# Pred: [38, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 978
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0142 - val_loss: -0.0170
# Orig: [49, 49, 49, 53, 27]
# Pred: [49, 49, 49, 53, 9]
#
# --------------------------------------------------
# Iteration 979
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0136 - val_loss: -0.0153
# Orig: [49, 49, 41, 49, 34]
# Pred: [49, 49, 49, 49, 41]
#
# --------------------------------------------------
# Iteration 980
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0138 - val_loss: -0.0161
# Orig: [49, 51, 46, 49, 49]
# Pred: [49, 51, 9, 49, 49]
#
# --------------------------------------------------
# Iteration 981
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0179 - val_loss: -0.0143
# Orig: [49, 49, 38, 49, 49]
# Pred: [49, 49, 38, 49, 49]
#
# --------------------------------------------------
# Iteration 982
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0165 - val_loss: -0.0143
# Orig: [34, 55, 50, 41, 49]
# Pred: [55, 50, 50, 50, 49]
#
# --------------------------------------------------
# Iteration 983
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0138 - val_loss: -0.0136
# Orig: [49, 51, 49, 57, 38]
# Pred: [49, 49, 49, 57, 57]
#
# --------------------------------------------------
# Iteration 984
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0165 - val_loss: -0.0140
# Orig: [49, 49, 57, 51, 57]
# Pred: [49, 49, 57, 57, 57]
#
# --------------------------------------------------
# Iteration 985
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0155 - val_loss: -0.0147
# Orig: [49, 54, 57, 45, 49]
# Pred: [49, 45, 57, 57, 49]
#
# --------------------------------------------------
# Iteration 986
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0140 - val_loss: -0.0156
# Orig: [46, 49, 49, 49, 49]
# Pred: [46, 49, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 987
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0142 - val_loss: -0.0149
# Orig: [57, 45, 41, 49, 47]
# Pred: [57, 45, 45, 49, 49]
#
# --------------------------------------------------
# Iteration 988
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0149 - val_loss: -0.0145
# Orig: [49, 49, 49, 49, 44]
# Pred: [49, 49, 49, 49, 44]
#
# --------------------------------------------------
# Iteration 989
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0131 - val_loss: -0.0152
# Orig: [52, 49, 49, 56, 67]
# Pred: [52, 49, 49, 56, 9]
#
# --------------------------------------------------
# Iteration 990
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0167 - val_loss: -0.0155
# Orig: [49, 49, 49, 49, 46]
# Pred: [49, 49, 49, 49, 46]
#
# --------------------------------------------------
# Iteration 991
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0137 - val_loss: -0.0147
# Orig: [41, 49, 37, 49, 53]
# Pred: [41, 49, 49, 49, 9]
#
# --------------------------------------------------
# Iteration 992
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0170 - val_loss: -0.0155
# Orig: [47, 48, 56, 49, 49]
# Pred: [48, 74, 47, 49, 49]
#
# --------------------------------------------------
# Iteration 993
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0157 - val_loss: -0.0143
# Orig: [40, 49, 49, 49, 56]
# Pred: [40, 49, 49, 49, 9]
#
# --------------------------------------------------
# Iteration 994
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0161 - val_loss: -0.0138
# Orig: [48, 24, 47, 49, 49]
# Pred: [48, 9, 47, 49, 49]
#
# --------------------------------------------------
# Iteration 995
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0166 - val_loss: -0.0165
# Orig: [52, 52, 49, 49, 49]
# Pred: [52, 52, 49, 49, 49]
#
# --------------------------------------------------
# Iteration 996
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0140 - val_loss: -0.0153
# Orig: [52, 49, 49, 52, 47]
# Pred: [52, 49, 49, 52, 9]
#
# --------------------------------------------------
# Iteration 997
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0160 - val_loss: -0.0157
# Orig: [51, 49, 47, 49, 40]
# Pred: [51, 49, 49, 49, 9]
#
# --------------------------------------------------
# Iteration 998
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0161 - val_loss: -0.0133
# Orig: [40, 45, 57, 49, 49]
# Pred: [45, 11, 57, 49, 49]
#
# --------------------------------------------------
# Iteration 999
# Train on 32 samples, validate on 32 samples
# Epoch 1/1
# 32/32 [==============================] - 0s - loss: -0.0168 - val_loss: -0.0153
# Orig: [34, 49, 49, 49, 47]
# Pred: [34, 49, 49, 49, 34]
# 'history = model.fit_generator(train_generator, \n                              samples_per_epoch=len(train_samples), \n                              validation_data=validation_generator, \n                              nb_val_samples=len(validation_samples), \n                              nb_epoch=NUM_EPOCHS)'

# %%
import pandas as pd
data = pd.read_csv('../../data/driving_log_udacity.csv')

# %%
data.describe()
# Out:
#                  0          0.1          0.2     22.14829
# count  8035.000000  8035.000000  8035.000000  8035.000000
# mean      0.004070     0.869768     0.001970    28.170589
# std       0.128848     0.301188     0.036567     6.149343
# min      -0.942695     0.000000     0.000000     0.502490
# 25%       0.000000     0.985533     0.000000    30.183100
# 50%       0.000000     0.985533     0.000000    30.186400
# 75%       0.000000     0.985533     0.000000    30.186640
# max       1.000000     0.985533     1.000000    30.709360
